# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
business_df = pd.read_csv('../data/businesses.csv')
crime_df = pd.read_csv('../data/crimes.csv')
inspection_df = pd.read_csv("../data/inspections.csv")
garbage_df = pd.read_csv('../data/garbage.csv')
sanitation_df = pd.read_csv('../data/sanitation.csv')

# %%
# Clean the Inspection Dataframe
inspection_df = pd.read_csv("../data/inspections.csv")
del inspection_df['city']
del inspection_df['Unnamed: 0']
del inspection_df['location_address']
del inspection_df['location_zip']
del inspection_df['location_city']
del inspection_df['location_state']
inspection_df['inspection_date'] = pd.to_datetime(inspection_df['inspection_date'])


inspection_df.head()
# Out:
#                       address                      aka_name  \
# 0         217 N JEFFERSON ST             TRATTORIA ISABELLA
# 1  2715 N Milwaukee AVE BLDG                     FIESTA UNO
# 2           530 N WABASH AVE        P.F. CHANG CHINA BISTRO
# 3             517 S STATE ST                    EPIC BURGER
# 4          3401 W AINSLIE ST   ALBANY PARK COMMUNITY CENTER
#
#                        dba_name                 facility_type inspection_date  \
# 0            TRATTORIA ISABELLA                    Restaurant      2012-04-06
# 1                     FISTA UNO                    Restaurant      2010-12-09
# 2       P.F. CHANG CHINA BISTRO                    Restaurant      2011-10-14
# 3                   EPIC BURGER                    Restaurant      2013-10-03
# 4  ALBANY PARK COMMUNITY CENTER  Children's Services Facility      2015-09-09
#
#    inspection_id        inspection_type   latitude  license_  \
# 0        1184245                Canvass  41.886294   1842843
# ...

# %%
# convert time strings to dates
inspection_df['inspection_date'] = pd.to_datetime(inspection_df['inspection_date'])
garbage_df['completion_date']  = pd.to_datetime(garbage_df['completion_date'])
garbage_df['creation_date'] = pd.to_datetime(garbage_df['creation_date'])
sanitation_df['completion_date']  = pd.to_datetime(sanitation_df['completion_date'])
sanitation_df['creation_date'] = pd.to_datetime(sanitation_df['creation_date'])
crime_df['date'] = pd.to_datetime(crime_df['date'])
